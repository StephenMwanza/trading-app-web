# %%
import pandas as pd
from ta import add_all_ta_features
from ta.utils import dropna

# %%
# Out:
#                      ('bid', 'Open')  ('bid', 'High')  ('bid', 'Low')  \
# 2022-12-30 12:00:00          33102.4          33113.9         33069.9
# 2022-12-30 13:00:00          33078.9          33086.9         33043.9
# 2022-12-30 14:00:00          33066.9          33107.5         32909.0
# 2022-12-30 15:00:00          32993.5          33074.5         32930.0
# 2022-12-30 16:00:00          32977.5          33016.6         32907.5
# ...                              ...              ...             ...
# 2023-03-01 08:00:00          32695.0          32729.5         32659.5
# 2023-03-01 09:00:00          32706.5          32742.0         32670.5
# 2023-03-01 10:00:00          32692.5          32722.0         32671.5
# 2023-03-01 11:00:00          32720.5          32735.0         32704.5
# 2023-03-01 12:00:00          32710.5          32723.0         32689.5
#
#                      ('bid', 'Close')  ('ask', 'Open')  ('ask', 'High')  \
# ...

# %%
# Load datas
df = pd.read_csv('data/test-data.csv', sep=',' index)
# Out:
#                Unnamed: 0      bid    bid.1    bid.2    bid.3      ask  \
# 0                     NaN     Open     High      Low    Close     Open
# 1                DateTime      NaN      NaN      NaN      NaN      NaN
# 2     2022-12-30 12:00:00  33102.4  33113.9  33069.9  33079.4  33106.0
# 3     2022-12-30 13:00:00  33078.9  33086.9  33043.9  33067.4  33082.5
# 4     2022-12-30 14:00:00  33066.9  33107.5  32909.0  32993.0  33070.5
# ...                   ...      ...      ...      ...      ...      ...
# 997   2023-03-01 08:00:00  32695.0  32729.5  32659.5  32709.0  32698.6
# 998   2023-03-01 09:00:00  32706.5  32742.0  32670.5  32692.0  32710.1
# 999   2023-03-01 10:00:00  32692.5  32722.0  32671.5  32720.0  32696.1
# 1000  2023-03-01 11:00:00  32720.5  32735.0  32704.5  32710.0  32724.1
# 1001  2023-03-01 12:00:00  32710.5  32723.0  32689.5  32717.5  32714.1
#
#         ask.1    ask.2    ask.3
# 0        High      Low    Close
# 1         NaN      NaN      NaN
# ...

# %%
# Clean NaN values
df = dropna(df)
df
# Out:
#                Unnamed: 0      bid    bid.1    bid.2    bid.3      ask  \
# 2     2022-12-30 12:00:00  33102.4  33113.9  33069.9  33079.4  33106.0
# 3     2022-12-30 13:00:00  33078.9  33086.9  33043.9  33067.4  33082.5
# 4     2022-12-30 14:00:00  33066.9  33107.5  32909.0  32993.0  33070.5
# 5     2022-12-30 15:00:00  32993.5  33074.5  32930.0  32977.0  32995.9
# 6     2022-12-30 16:00:00  32977.5  33016.6  32907.5  33002.6  32979.9
# ...                   ...      ...      ...      ...      ...      ...
# 997   2023-03-01 08:00:00  32695.0  32729.5  32659.5  32709.0  32698.6
# 998   2023-03-01 09:00:00  32706.5  32742.0  32670.5  32692.0  32710.1
# 999   2023-03-01 10:00:00  32692.5  32722.0  32671.5  32720.0  32696.1
# 1000  2023-03-01 11:00:00  32720.5  32735.0  32704.5  32710.0  32724.1
# 1001  2023-03-01 12:00:00  32710.5  32723.0  32689.5  32717.5  32714.1
#
#         ask.1    ask.2    ask.3
# 2     33117.5  33073.5  33083.0
# 3     33090.5  33047.5  33071.0
# ...

# %%
analysis[['bid', 'bid.1', 'bid.2', 'bid.3']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_9348/3476893467.py in <module>
# ----> 1 analysis[['bid', 'bid.1', 'bid.2', 'bid.3']]
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# ...
